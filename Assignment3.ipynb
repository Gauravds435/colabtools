# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravds435/colabtools/blob/master/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_table("http://bit.ly/kaggletrain", sep=",")
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.Survived.value_counts().plot.bar()

# %%
sns.countplot(x="Survived",data=df, hue = "Sex")

# %%
sns.lineplot(x="Age", y="Fare", data=df)

# %%
sns.lineplot(x="Pclass", y="Fare", data=df)

# %%
df.plot.scatter("Age", "Survived")

# %%
df.plot.scatter("Age", "Fare")

# %%
df["Age"].hist(bins=10)

# %%
chart = df["Sex"].value_counts()
fig1, ax1 = plt.subplots()
ax1.pie(chart, labels=["Male","Female"], autopct="%1.1f%%", shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5b6b8731d0>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'Male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'Female')],
#  [Text(-0.2683338620074884, 0.5366534622082915, '64.8%'),
#   Text(0.26833391225261044, -0.53665343708506, '35.2%')])
